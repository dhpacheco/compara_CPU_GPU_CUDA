# %% [markdown]
# # Testes comparativos: GPU vs CPU

# %% [markdown]
# <p>O presente projeto busca realizar comparações de desempenho de processamento em CPU vs GPU para as tarefas de detecção facial e extração de embeddings faciais.</p>
#
# <p>Nestes testes, que serão executados em python, utilizaremos a seguinte metodologia:</p>
# <ol>
# <li>Leitura de imagens em arquivos JPG, da ordem de 1000  registros;</li>
# <li>Geração do DataFrame com os filenames e filepaths;</li>
# <li>Medição do tempo de extração de embeddings de cada imagem obtida.</li>
# </ol>
#
# <p>Será utilizada biblioteca específica (timeit) para avaliação do desempenho do algoritmo relacionado tão somente ao tempo para a extração dos embeddings faciais.</p>
#
#
# <p>Bibliotecas a serem utilizadas para processamento em CPU:</p>
# <ul>
# <li>timeit</li>
# <li>functools.partial</li>
# <li>Pandas</li>
# <li>Numpy</li>
# <li>Opencv</li>
# <li>DeepFace com os modelos Dlib, Facenet512 etc.</li>
# </ul>
# <p>Obs: O processamento em CPU deverá ser realizado em ambiente sem as configurações de CUDA aplicadas.</p>
# <hr>
#
# <p>Bibliotecas a serem utilizadas para processamento em GPU:</p>
# <ul>
# <li>timeit</li>
# <li>functools.partial</li>
# <li>Pandas</li>
# <li>Numpy</li>
# <li>Opencv</li>
# <li>DeepFace com os modelos Dlib, Facenet512 etc.</li>
# </ul>
# <p>Obs: O processamento em GPU deverá ser realizado em ambiente com as configurações de CUDA aplicadas.</p>

# %% [markdown]
# ## Processamento em GPU/CPU

# %%
# Verifica se o CUDA esta instalado e a versão correspondente
# !nvidia-smi
# Out:
# Tue Jun 25 22:45:16 2024
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 555.42.03              Driver Version: 555.85         CUDA Version: 12.5     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  NVIDIA GeForce RTX 3060 ...    On  |   00000000:01:00.0 Off |                  N/A |
# | N/A   49C    P5             16W /   30W |       0MiB /   6144MiB |      0%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI        PID   Type   Process name                              GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |  No running processes found                                                             |
# +-----------------------------------------------------------------------------------------+

# %%
# Import das bibliotecas
import pandas as pd
import numpy as np
import timeit
from functools import partial  # Para permitir a passagem de parametros dentro de timeit
import os
from PIL import Image
from deepface import DeepFace
import matplotlib.pyplot as plt
import tensorflow as tf;
# import cudf #nao utilizado, embora disponível.

print(tf.config.list_physical_devices('GPU'))
if tf.config.list_physical_devices('GPU'):
    print('GPU disponível.')
# Out:
# 2024-06-25 22:45:19.242006: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2024-06-25 22:45:19.255893: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1719366319.274706 1150758 cuda_dnn.cc:8453] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1719366319.279745 1150758 cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-06-25 22:45:19.293248: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-06-25 22:45:20.336789: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]
# GPU disponível.
# I0000 00:00:1719366322.399766 1150758 cuda_executor.cc:913] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# I0000 00:00:1719366322.426508 1150758 cuda_executor.cc:913] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# I0000 00:00:1719366322.426562 1150758 cuda_executor.cc:913] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.

# %%
PROCESSING_UNIT = 'CPU' # alterar para CPU ou GPU
IMAGES_PATH = './imagens/'      # Local das imagens
REPORT_PATH = './relatorios/'   # Local dos relatorios
N_LINES = 100                  # Qtd de imagens

# configurações básicas
if tf.config.list_physical_devices(PROCESSING_UNIT):
    print(PROCESSING_UNIT + ' disponível e configurada para uso.')

# Define os modelos
model_list = ['Dlib', 'Facenet512', 'Facenet', 'ArcFace', 'OpenFace', 'DeepID', 'DeepFace', 'GhostFaceNet', 'sFace'] # Face Embeddings Models
detector_list = ['opencv', 'ssd', 'dlib', 'mtcnn', 'retinaface','yolov8','yunet', 'fastmtcnn'] # Face Detection Models
# Out:
# CPU disponível e configurada para uso.

# %% [markdown]
# ### Funções

# %%
def read_files_recursively(folder_path, data=[]):
    """Le arquivos JPG em uma pasta, recursivamente, e os armazena em uma lista.

    Args:
        folder_path (str): O path da pasta raiz onde procurar arquivos.
        data (list, optional):  Lista para armazenar as informações dos arquivos. Defaults = [].

    Returns:
        list: Uma list de dict, cada um contendo informações do arquivo.
    """

    for root, _, filenames in os.walk(folder_path):
        for filename in filenames:
            if filename.lower().endswith('.jpg'):  # Filter for .jpg files
                file_path = os.path.join(root, filename)
                try:
                    # Add any additional file processing or checks here if needed
                    data.append({
                        'filename': filename,
                        'relative_path': os.path.relpath(file_path, './')
                    })
                except Exception as e:
                    print(f"Error processing {file_path}: {e}")  # Log errors 

    return data


# Função que extrai os embeddings faciais (vetores)
def gera_vetor(img_path, model_name='GhostFaceNet', detector_backend='yolov8', proc_unit='CPU'):
    with tf.device(f'/{PROCESSING_UNIT}:0'):
        # print(tf.device(f'/{PROCESSING_UNIT}:0'))
        return DeepFace.represent(img_path=img_path, model_name=model_name, detector_backend=detector_backend)



# Função que avalia o tempo de extração dos embeddings
def iteration_with_timing(df, row, model_name, detector_backend):  
    img_path = './' + row['relative_path'] 
    time_taken = timeit.timeit(partial(gera_vetor, img_path, model_name, detector_backend, proc_unit=PROCESSING_UNIT), number=1)
    df.loc[row.name, PROCESSING_UNIT+'_'+detector_backend+'_'+model_name] = time_taken  # Update DataFrame

# %% [markdown]
# ### Leitura dos arquivos

# %%
# Lê os arquivos
file_data = read_files_recursively(IMAGES_PATH)

# Cria a DataFrame
df = pd.DataFrame(file_data).iloc[0:N_LINES]

# Mostra o DF
df
# Out:
#             filename                                      relative_path
# 0   001_fe3347c0.jpg  imagens/Celebrity Faces Dataset/Angelina Jolie...
# 1   002_8f8da10e.jpg  imagens/Celebrity Faces Dataset/Angelina Jolie...
# 2   003_57612506.jpg  imagens/Celebrity Faces Dataset/Angelina Jolie...
# 3   004_f61e7d0c.jpg  imagens/Celebrity Faces Dataset/Angelina Jolie...
# 4   005_582c121a.jpg  imagens/Celebrity Faces Dataset/Angelina Jolie...
# ..               ...                                                ...
# 95  096_75710434.jpg  imagens/Celebrity Faces Dataset/Angelina Jolie...
# 96  097_9a6bf61f.jpg  imagens/Celebrity Faces Dataset/Angelina Jolie...
# 97  098_dd1405fc.jpg  imagens/Celebrity Faces Dataset/Angelina Jolie...
# 98  099_c22d3e48.jpg  imagens/Celebrity Faces Dataset/Angelina Jolie...
# 99  100_31ff9373.jpg  imagens/Celebrity Faces Dataset/Angelina Jolie...
#
# [100 rows x 2 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 2 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   filename       100 non-null    object
#  1   relative_path  100 non-null    object
# dtypes: object(2)
# memory usage: 1.7+ KB

# %% [markdown]
# ### Execução

# %%
# Inicia o loop
for d in detector_list:
    
    for m in model_list:
        
        print(f'running m:{m} | d: {d}...')
        print(tf.device(f'/{PROCESSING_UNIT}:0'))
        df[PROCESSING_UNIT+'_'+d+'_'+m] = None

        for index, row in df.iterrows():
            try:
                img_path = './' + row['relative_path'] 
                iteration_with_timing(df, row, m, d);  # Aciona a função de timing que irá acionar a função gera_vetor()

            except:
                print(f'linha {str(index)} nao tem face... m:{m} | d: {d}')

                pass

# Grava o resultado em um arquivo CSV            
df.to_csv(REPORT_PATH + PROCESSING_UNIT+'_all_models'+'_'+str(N_LINES)+'.csv', sep=';')
# Out:
# running m:Dlib | d: opencv...
# linha 0 nao tem face... m:Dlib | d: opencv
# linha 1 nao tem face... m:Dlib | d: opencv
# linha 2 nao tem face... m:Dlib | d: opencv
# linha 3 nao tem face... m:Dlib | d: opencv
# linha 4 nao tem face... m:Dlib | d: opencv
# linha 5 nao tem face... m:Dlib | d: opencv
# linha 6 nao tem face... m:Dlib | d: opencv
# linha 7 nao tem face... m:Dlib | d: opencv
# linha 8 nao tem face... m:Dlib | d: opencv
# linha 9 nao tem face... m:Dlib | d: opencv
# linha 10 nao tem face... m:Dlib | d: opencv
# linha 11 nao tem face... m:Dlib | d: opencv
# linha 12 nao tem face... m:Dlib | d: opencv
# linha 13 nao tem face... m:Dlib | d: opencv
# linha 14 nao tem face... m:Dlib | d: opencv
# linha 15 nao tem face... m:Dlib | d: opencv
# linha 16 nao tem face... m:Dlib | d: opencv
# linha 17 nao tem face... m:Dlib | d: opencv
# linha 18 nao tem face... m:Dlib | d: opencv
# linha 19 nao tem face... m:Dlib | d: opencv
# linha 20 nao tem face... m:Dlib | d: opencv
# linha 21 nao tem face... m:Dlib | d: opencv
# linha 22 nao tem face... m:Dlib | d: opencv
# linha 23 nao tem face... m:Dlib | d: opencv
# linha 24 nao tem face... m:Dlib | d: opencv
# linha 25 nao tem face... m:Dlib | d: opencv
# linha 26 nao tem face... m:Dlib | d: opencv
# linha 27 nao tem face... m:Dlib | d: opencv
# linha 28 nao tem face... m:Dlib | d: opencv
# linha 29 nao tem face... m:Dlib | d: opencv
# linha 30 nao tem face... m:Dlib | d: opencv
# linha 31 nao tem face... m:Dlib | d: opencv
# linha 32 nao tem face... m:Dlib | d: opencv
# linha 33 nao tem face... m:Dlib | d: opencv
# linha 34 nao tem face... m:Dlib | d: opencv
# linha 35 nao tem face... m:Dlib | d: opencv
# linha 36 nao tem face... m:Dlib | d: opencv
# linha 37 nao tem face... m:Dlib | d: opencv
# linha 38 nao tem face... m:Dlib | d: opencv
# linha 39 nao tem face... m:Dlib | d: opencv
# linha 40 nao tem face... m:Dlib | d: opencv
# linha 41 nao tem face... m:Dlib | d: opencv
# linha 42 nao tem face... m:Dlib | d: opencv
# linha 43 nao tem face... m:Dlib | d: opencv
# linha 44 nao tem face... m:Dlib | d: opencv
# linha 45 nao tem face... m:Dlib | d: opencv
# linha 46 nao tem face... m:Dlib | d: opencv
# linha 47 nao tem face... m:Dlib | d: opencv
# linha 48 nao tem face... m:Dlib | d: opencv
# linha 49 nao tem face... m:Dlib | d: opencv
# linha 50 nao tem face... m:Dlib | d: opencv
# linha 51 nao tem face... m:Dlib | d: opencv
# linha 52 nao tem face... m:Dlib | d: opencv
# linha 53 nao tem face... m:Dlib | d: opencv
# linha 54 nao tem face... m:Dlib | d: opencv
# linha 55 nao tem face... m:Dlib | d: opencv
# linha 56 nao tem face... m:Dlib | d: opencv
# linha 57 nao tem face... m:Dlib | d: opencv
# linha 58 nao tem face... m:Dlib | d: opencv
# linha 59 nao tem face... m:Dlib | d: opencv
# linha 60 nao tem face... m:Dlib | d: opencv
# linha 61 nao tem face... m:Dlib | d: opencv
# linha 62 nao tem face... m:Dlib | d: opencv
# linha 63 nao tem face... m:Dlib | d: opencv
# linha 64 nao tem face... m:Dlib | d: opencv
# linha 65 nao tem face... m:Dlib | d: opencv
# linha 66 nao tem face... m:Dlib | d: opencv
# linha 67 nao tem face... m:Dlib | d: opencv
# linha 68 nao tem face... m:Dlib | d: opencv
# linha 69 nao tem face... m:Dlib | d: opencv
# linha 70 nao tem face... m:Dlib | d: opencv
# linha 71 nao tem face... m:Dlib | d: opencv
# linha 72 nao tem face... m:Dlib | d: opencv
# linha 73 nao tem face... m:Dlib | d: opencv
# linha 74 nao tem face... m:Dlib | d: opencv
# linha 75 nao tem face... m:Dlib | d: opencv
# linha 76 nao tem face... m:Dlib | d: opencv
# linha 77 nao tem face... m:Dlib | d: opencv
# linha 78 nao tem face... m:Dlib | d: opencv
# linha 79 nao tem face... m:Dlib | d: opencv
# linha 80 nao tem face... m:Dlib | d: opencv
# linha 81 nao tem face... m:Dlib | d: opencv
# linha 82 nao tem face... m:Dlib | d: opencv
# linha 83 nao tem face... m:Dlib | d: opencv
# linha 84 nao tem face... m:Dlib | d: opencv
# linha 85 nao tem face... m:Dlib | d: opencv
# linha 86 nao tem face... m:Dlib | d: opencv
# linha 87 nao tem face... m:Dlib | d: opencv
# linha 88 nao tem face... m:Dlib | d: opencv
# linha 89 nao tem face... m:Dlib | d: opencv
# linha 90 nao tem face... m:Dlib | d: opencv
# linha 91 nao tem face... m:Dlib | d: opencv
# linha 92 nao tem face... m:Dlib | d: opencv
# linha 93 nao tem face... m:Dlib | d: opencv
# linha 94 nao tem face... m:Dlib | d: opencv
# linha 95 nao tem face... m:Dlib | d: opencv
# linha 96 nao tem face... m:Dlib | d: opencv
# linha 97 nao tem face... m:Dlib | d: opencv
# linha 98 nao tem face... m:Dlib | d: opencv
# linha 99 nao tem face... m:Dlib | d: opencv
# running m:Facenet512 | d: opencv...
# I0000 00:00:1719366652.851678 1150758 cuda_executor.cc:913] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# I0000 00:00:1719366652.851959 1150758 cuda_executor.cc:913] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# I0000 00:00:1719366652.852024 1150758 cuda_executor.cc:913] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# I0000 00:00:1719366654.984866 1150758 cuda_executor.cc:913] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# I0000 00:00:1719366654.984933 1150758 cuda_executor.cc:913] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# I0000 00:00:1719366654.984937 1150758 gpu_device.cc:2113] Could not identify NUMA node of platform GPU id 0, defaulting to 0.  Your kernel may not have been built with NUMA support.
# 2024-06-25 22:50:54.984952: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:47] Overriding orig_value setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# I0000 00:00:1719366654.984977 1150758 cuda_executor.cc:913] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# I0000 00:00:1719366655.031619 1150758 gpu_device.cc:2022] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 3586 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 3060 Laptop GPU, pci bus id: 0000:01:00.0, compute capability: 8.6
# linha 60 nao tem face... m:Facenet512 | d: opencv
# linha 74 nao tem face... m:Facenet512 | d: opencv
# running m:Facenet | d: opencv...
# linha 60 nao tem face... m:Facenet | d: opencv
# linha 74 nao tem face... m:Facenet | d: opencv
# running m:ArcFace | d: opencv...
# linha 60 nao tem face... m:ArcFace | d: opencv
# linha 74 nao tem face... m:ArcFace | d: opencv
# running m:OpenFace | d: opencv...
# linha 60 nao tem face... m:OpenFace | d: opencv
# linha 74 nao tem face... m:OpenFace | d: opencv
# running m:DeepID | d: opencv...
# linha 60 nao tem face... m:DeepID | d: opencv
# linha 74 nao tem face... m:DeepID | d: opencv
# running m:DeepFace | d: opencv...
# linha 0 nao tem face... m:DeepFace | d: opencv
# linha 1 nao tem face... m:DeepFace | d: opencv
# linha 2 nao tem face... m:DeepFace | d: opencv
# linha 3 nao tem face... m:DeepFace | d: opencv
# linha 4 nao tem face... m:DeepFace | d: opencv
# linha 5 nao tem face... m:DeepFace | d: opencv
# linha 6 nao tem face... m:DeepFace | d: opencv
# linha 7 nao tem face... m:DeepFace | d: opencv
# linha 8 nao tem face... m:DeepFace | d: opencv
# linha 9 nao tem face... m:DeepFace | d: opencv
# linha 10 nao tem face... m:DeepFace | d: opencv
# linha 11 nao tem face... m:DeepFace | d: opencv
# linha 12 nao tem face... m:DeepFace | d: opencv
# linha 13 nao tem face... m:DeepFace | d: opencv
# linha 14 nao tem face... m:DeepFace | d: opencv
# linha 15 nao tem face... m:DeepFace | d: opencv
# linha 16 nao tem face... m:DeepFace | d: opencv
# linha 17 nao tem face... m:DeepFace | d: opencv
# linha 18 nao tem face... m:DeepFace | d: opencv
# linha 19 nao tem face... m:DeepFace | d: opencv
# linha 20 nao tem face... m:DeepFace | d: opencv
# linha 21 nao tem face... m:DeepFace | d: opencv
# linha 22 nao tem face... m:DeepFace | d: opencv
# linha 23 nao tem face... m:DeepFace | d: opencv
# linha 24 nao tem face... m:DeepFace | d: opencv
# linha 25 nao tem face... m:DeepFace | d: opencv
# linha 26 nao tem face... m:DeepFace | d: opencv
# linha 27 nao tem face... m:DeepFace | d: opencv
# linha 28 nao tem face... m:DeepFace | d: opencv
# linha 29 nao tem face... m:DeepFace | d: opencv
# linha 30 nao tem face... m:DeepFace | d: opencv
# linha 31 nao tem face... m:DeepFace | d: opencv
# linha 32 nao tem face... m:DeepFace | d: opencv
# linha 33 nao tem face... m:DeepFace | d: opencv
# linha 34 nao tem face... m:DeepFace | d: opencv
# linha 35 nao tem face... m:DeepFace | d: opencv
# linha 36 nao tem face... m:DeepFace | d: opencv
# linha 37 nao tem face... m:DeepFace | d: opencv
# linha 38 nao tem face... m:DeepFace | d: opencv
# linha 39 nao tem face... m:DeepFace | d: opencv
# linha 40 nao tem face... m:DeepFace | d: opencv
# linha 41 nao tem face... m:DeepFace | d: opencv
# linha 42 nao tem face... m:DeepFace | d: opencv
# linha 43 nao tem face... m:DeepFace | d: opencv
# linha 44 nao tem face... m:DeepFace | d: opencv
# linha 45 nao tem face... m:DeepFace | d: opencv
# linha 46 nao tem face... m:DeepFace | d: opencv
# linha 47 nao tem face... m:DeepFace | d: opencv
# linha 48 nao tem face... m:DeepFace | d: opencv
# linha 49 nao tem face... m:DeepFace | d: opencv
# linha 50 nao tem face... m:DeepFace | d: opencv
# linha 51 nao tem face... m:DeepFace | d: opencv
# linha 52 nao tem face... m:DeepFace | d: opencv
# linha 53 nao tem face... m:DeepFace | d: opencv
# linha 54 nao tem face... m:DeepFace | d: opencv
# linha 55 nao tem face... m:DeepFace | d: opencv
# linha 56 nao tem face... m:DeepFace | d: opencv
# linha 57 nao tem face... m:DeepFace | d: opencv
# linha 58 nao tem face... m:DeepFace | d: opencv
# linha 59 nao tem face... m:DeepFace | d: opencv
# linha 60 nao tem face... m:DeepFace | d: opencv
# linha 61 nao tem face... m:DeepFace | d: opencv
# linha 62 nao tem face... m:DeepFace | d: opencv
# linha 63 nao tem face... m:DeepFace | d: opencv
# linha 64 nao tem face... m:DeepFace | d: opencv
# linha 65 nao tem face... m:DeepFace | d: opencv
# linha 66 nao tem face... m:DeepFace | d: opencv
# linha 67 nao tem face... m:DeepFace | d: opencv
# linha 68 nao tem face... m:DeepFace | d: opencv
# linha 69 nao tem face... m:DeepFace | d: opencv
# linha 70 nao tem face... m:DeepFace | d: opencv
# linha 71 nao tem face... m:DeepFace | d: opencv
# linha 72 nao tem face... m:DeepFace | d: opencv
# linha 73 nao tem face... m:DeepFace | d: opencv
# linha 74 nao tem face... m:DeepFace | d: opencv
# linha 75 nao tem face... m:DeepFace | d: opencv
# linha 76 nao tem face... m:DeepFace | d: opencv
# linha 77 nao tem face... m:DeepFace | d: opencv
# linha 78 nao tem face... m:DeepFace | d: opencv
# linha 79 nao tem face... m:DeepFace | d: opencv
# linha 80 nao tem face... m:DeepFace | d: opencv
# linha 81 nao tem face... m:DeepFace | d: opencv
# linha 82 nao tem face... m:DeepFace | d: opencv
# linha 83 nao tem face... m:DeepFace | d: opencv
# linha 84 nao tem face... m:DeepFace | d: opencv
# linha 85 nao tem face... m:DeepFace | d: opencv
# linha 86 nao tem face... m:DeepFace | d: opencv
# linha 87 nao tem face... m:DeepFace | d: opencv
# linha 88 nao tem face... m:DeepFace | d: opencv
# linha 89 nao tem face... m:DeepFace | d: opencv
# linha 90 nao tem face... m:DeepFace | d: opencv
# linha 91 nao tem face... m:DeepFace | d: opencv
# linha 92 nao tem face... m:DeepFace | d: opencv
# linha 93 nao tem face... m:DeepFace | d: opencv
# linha 94 nao tem face... m:DeepFace | d: opencv
# linha 95 nao tem face... m:DeepFace | d: opencv
# linha 96 nao tem face... m:DeepFace | d: opencv
# linha 97 nao tem face... m:DeepFace | d: opencv
# linha 98 nao tem face... m:DeepFace | d: opencv
# linha 99 nao tem face... m:DeepFace | d: opencv
# running m:GhostFaceNet | d: opencv...
# linha 60 nao tem face... m:GhostFaceNet | d: opencv
# linha 74 nao tem face... m:GhostFaceNet | d: opencv
# running m:sFace | d: opencv...
# linha 0 nao tem face... m:sFace | d: opencv
# linha 1 nao tem face... m:sFace | d: opencv
# linha 2 nao tem face... m:sFace | d: opencv
# linha 3 nao tem face... m:sFace | d: opencv
# linha 4 nao tem face... m:sFace | d: opencv
# linha 5 nao tem face... m:sFace | d: opencv
# linha 6 nao tem face... m:sFace | d: opencv
# linha 7 nao tem face... m:sFace | d: opencv
# linha 8 nao tem face... m:sFace | d: opencv
# linha 9 nao tem face... m:sFace | d: opencv
# linha 10 nao tem face... m:sFace | d: opencv
# linha 11 nao tem face... m:sFace | d: opencv
# linha 12 nao tem face... m:sFace | d: opencv
# linha 13 nao tem face... m:sFace | d: opencv
# linha 14 nao tem face... m:sFace | d: opencv
# linha 15 nao tem face... m:sFace | d: opencv
# linha 16 nao tem face... m:sFace | d: opencv
# linha 17 nao tem face... m:sFace | d: opencv
# linha 18 nao tem face... m:sFace | d: opencv
# linha 19 nao tem face... m:sFace | d: opencv
# linha 20 nao tem face... m:sFace | d: opencv
# linha 21 nao tem face... m:sFace | d: opencv
# linha 22 nao tem face... m:sFace | d: opencv
# linha 23 nao tem face... m:sFace | d: opencv
# linha 24 nao tem face... m:sFace | d: opencv
# linha 25 nao tem face... m:sFace | d: opencv
# linha 26 nao tem face... m:sFace | d: opencv
# linha 27 nao tem face... m:sFace | d: opencv
# linha 28 nao tem face... m:sFace | d: opencv
# linha 29 nao tem face... m:sFace | d: opencv
# linha 30 nao tem face... m:sFace | d: opencv
# linha 31 nao tem face... m:sFace | d: opencv
# linha 32 nao tem face... m:sFace | d: opencv
# linha 33 nao tem face... m:sFace | d: opencv
# linha 34 nao tem face... m:sFace | d: opencv
# linha 35 nao tem face... m:sFace | d: opencv
# linha 36 nao tem face... m:sFace | d: opencv
# linha 37 nao tem face... m:sFace | d: opencv
# linha 38 nao tem face... m:sFace | d: opencv
# linha 39 nao tem face... m:sFace | d: opencv
# linha 40 nao tem face... m:sFace | d: opencv
# linha 41 nao tem face... m:sFace | d: opencv
# linha 42 nao tem face... m:sFace | d: opencv
# linha 43 nao tem face... m:sFace | d: opencv
# linha 44 nao tem face... m:sFace | d: opencv
# linha 45 nao tem face... m:sFace | d: opencv
# linha 46 nao tem face... m:sFace | d: opencv
# linha 47 nao tem face... m:sFace | d: opencv
# linha 48 nao tem face... m:sFace | d: opencv
# linha 49 nao tem face... m:sFace | d: opencv
# linha 50 nao tem face... m:sFace | d: opencv
# linha 51 nao tem face... m:sFace | d: opencv
# linha 52 nao tem face... m:sFace | d: opencv
# linha 53 nao tem face... m:sFace | d: opencv
# linha 54 nao tem face... m:sFace | d: opencv
# linha 55 nao tem face... m:sFace | d: opencv
# linha 56 nao tem face... m:sFace | d: opencv
# linha 57 nao tem face... m:sFace | d: opencv
# linha 58 nao tem face... m:sFace | d: opencv
# linha 59 nao tem face... m:sFace | d: opencv
# linha 60 nao tem face... m:sFace | d: opencv
# linha 61 nao tem face... m:sFace | d: opencv
# linha 62 nao tem face... m:sFace | d: opencv
# linha 63 nao tem face... m:sFace | d: opencv
# linha 64 nao tem face... m:sFace | d: opencv
# linha 65 nao tem face... m:sFace | d: opencv
# linha 66 nao tem face... m:sFace | d: opencv
# linha 67 nao tem face... m:sFace | d: opencv
# linha 68 nao tem face... m:sFace | d: opencv
# linha 69 nao tem face... m:sFace | d: opencv
# linha 70 nao tem face... m:sFace | d: opencv
# linha 71 nao tem face... m:sFace | d: opencv
# linha 72 nao tem face... m:sFace | d: opencv
# linha 73 nao tem face... m:sFace | d: opencv
# linha 74 nao tem face... m:sFace | d: opencv
# linha 75 nao tem face... m:sFace | d: opencv
# linha 76 nao tem face... m:sFace | d: opencv
# linha 77 nao tem face... m:sFace | d: opencv
# linha 78 nao tem face... m:sFace | d: opencv
# linha 79 nao tem face... m:sFace | d: opencv
# linha 80 nao tem face... m:sFace | d: opencv
# linha 81 nao tem face... m:sFace | d: opencv
# linha 82 nao tem face... m:sFace | d: opencv
# linha 83 nao tem face... m:sFace | d: opencv
# linha 84 nao tem face... m:sFace | d: opencv
# linha 85 nao tem face... m:sFace | d: opencv
# linha 86 nao tem face... m:sFace | d: opencv
# linha 87 nao tem face... m:sFace | d: opencv
# linha 88 nao tem face... m:sFace | d: opencv
# linha 89 nao tem face... m:sFace | d: opencv
# linha 90 nao tem face... m:sFace | d: opencv
# linha 91 nao tem face... m:sFace | d: opencv
# linha 92 nao tem face... m:sFace | d: opencv
# linha 93 nao tem face... m:sFace | d: opencv
# linha 94 nao tem face... m:sFace | d: opencv
# linha 95 nao tem face... m:sFace | d: opencv
# linha 96 nao tem face... m:sFace | d: opencv
# linha 97 nao tem face... m:sFace | d: opencv
# linha 98 nao tem face... m:sFace | d: opencv
# linha 99 nao tem face... m:sFace | d: opencv
# running m:Dlib | d: ssd...
# linha 0 nao tem face... m:Dlib | d: ssd
# linha 1 nao tem face... m:Dlib | d: ssd
# linha 2 nao tem face... m:Dlib | d: ssd
# linha 3 nao tem face... m:Dlib | d: ssd
# linha 4 nao tem face... m:Dlib | d: ssd
# linha 5 nao tem face... m:Dlib | d: ssd
# linha 6 nao tem face... m:Dlib | d: ssd
# linha 7 nao tem face... m:Dlib | d: ssd
# linha 8 nao tem face... m:Dlib | d: ssd
# linha 9 nao tem face... m:Dlib | d: ssd
# linha 10 nao tem face... m:Dlib | d: ssd
# linha 11 nao tem face... m:Dlib | d: ssd
# linha 12 nao tem face... m:Dlib | d: ssd
# linha 13 nao tem face... m:Dlib | d: ssd
# linha 14 nao tem face... m:Dlib | d: ssd
# linha 15 nao tem face... m:Dlib | d: ssd
# linha 16 nao tem face... m:Dlib | d: ssd
# linha 17 nao tem face... m:Dlib | d: ssd
# linha 18 nao tem face... m:Dlib | d: ssd
# linha 19 nao tem face... m:Dlib | d: ssd
# linha 20 nao tem face... m:Dlib | d: ssd
# linha 21 nao tem face... m:Dlib | d: ssd
# linha 22 nao tem face... m:Dlib | d: ssd
# linha 23 nao tem face... m:Dlib | d: ssd
# linha 24 nao tem face... m:Dlib | d: ssd
# linha 25 nao tem face... m:Dlib | d: ssd
# linha 26 nao tem face... m:Dlib | d: ssd
# linha 27 nao tem face... m:Dlib | d: ssd
# linha 28 nao tem face... m:Dlib | d: ssd
# linha 29 nao tem face... m:Dlib | d: ssd
# linha 30 nao tem face... m:Dlib | d: ssd
# linha 31 nao tem face... m:Dlib | d: ssd
# linha 32 nao tem face... m:Dlib | d: ssd
# linha 33 nao tem face... m:Dlib | d: ssd
# linha 34 nao tem face... m:Dlib | d: ssd
# linha 35 nao tem face... m:Dlib | d: ssd
# linha 36 nao tem face... m:Dlib | d: ssd
# linha 37 nao tem face... m:Dlib | d: ssd
# linha 38 nao tem face... m:Dlib | d: ssd
# linha 39 nao tem face... m:Dlib | d: ssd
# linha 40 nao tem face... m:Dlib | d: ssd
# linha 41 nao tem face... m:Dlib | d: ssd
# linha 42 nao tem face... m:Dlib | d: ssd
# linha 43 nao tem face... m:Dlib | d: ssd
# linha 44 nao tem face... m:Dlib | d: ssd
# linha 45 nao tem face... m:Dlib | d: ssd
# linha 46 nao tem face... m:Dlib | d: ssd
# linha 47 nao tem face... m:Dlib | d: ssd
# linha 48 nao tem face... m:Dlib | d: ssd
# linha 49 nao tem face... m:Dlib | d: ssd
# linha 50 nao tem face... m:Dlib | d: ssd
# linha 51 nao tem face... m:Dlib | d: ssd
# linha 52 nao tem face... m:Dlib | d: ssd
# linha 53 nao tem face... m:Dlib | d: ssd
# linha 54 nao tem face... m:Dlib | d: ssd
# linha 55 nao tem face... m:Dlib | d: ssd
# linha 56 nao tem face... m:Dlib | d: ssd
# linha 57 nao tem face... m:Dlib | d: ssd
# linha 58 nao tem face... m:Dlib | d: ssd
# linha 59 nao tem face... m:Dlib | d: ssd
# linha 60 nao tem face... m:Dlib | d: ssd
# linha 61 nao tem face... m:Dlib | d: ssd
# linha 62 nao tem face... m:Dlib | d: ssd
# linha 63 nao tem face... m:Dlib | d: ssd
# linha 64 nao tem face... m:Dlib | d: ssd
# linha 65 nao tem face... m:Dlib | d: ssd
# linha 66 nao tem face... m:Dlib | d: ssd
# linha 67 nao tem face... m:Dlib | d: ssd
# linha 68 nao tem face... m:Dlib | d: ssd
# linha 69 nao tem face... m:Dlib | d: ssd
# linha 70 nao tem face... m:Dlib | d: ssd
# linha 71 nao tem face... m:Dlib | d: ssd
# linha 72 nao tem face... m:Dlib | d: ssd
# linha 73 nao tem face... m:Dlib | d: ssd
# linha 74 nao tem face... m:Dlib | d: ssd
# linha 75 nao tem face... m:Dlib | d: ssd
# linha 76 nao tem face... m:Dlib | d: ssd
# linha 77 nao tem face... m:Dlib | d: ssd
# linha 78 nao tem face... m:Dlib | d: ssd
# linha 79 nao tem face... m:Dlib | d: ssd
# linha 80 nao tem face... m:Dlib | d: ssd
# linha 81 nao tem face... m:Dlib | d: ssd
# linha 82 nao tem face... m:Dlib | d: ssd
# linha 83 nao tem face... m:Dlib | d: ssd
# linha 84 nao tem face... m:Dlib | d: ssd
# linha 85 nao tem face... m:Dlib | d: ssd
# linha 86 nao tem face... m:Dlib | d: ssd
# linha 87 nao tem face... m:Dlib | d: ssd
# linha 88 nao tem face... m:Dlib | d: ssd
# linha 89 nao tem face... m:Dlib | d: ssd
# linha 90 nao tem face... m:Dlib | d: ssd
# linha 91 nao tem face... m:Dlib | d: ssd
# linha 92 nao tem face... m:Dlib | d: ssd
# linha 93 nao tem face... m:Dlib | d: ssd
# linha 94 nao tem face... m:Dlib | d: ssd
# linha 95 nao tem face... m:Dlib | d: ssd
# linha 96 nao tem face... m:Dlib | d: ssd
# linha 97 nao tem face... m:Dlib | d: ssd
# linha 98 nao tem face... m:Dlib | d: ssd
# linha 99 nao tem face... m:Dlib | d: ssd
# running m:Facenet512 | d: ssd...
# linha 98 nao tem face... m:Facenet512 | d: ssd
# running m:Facenet | d: ssd...
# linha 98 nao tem face... m:Facenet | d: ssd
# running m:ArcFace | d: ssd...
# linha 98 nao tem face... m:ArcFace | d: ssd
# running m:OpenFace | d: ssd...
# linha 98 nao tem face... m:OpenFace | d: ssd
# running m:DeepID | d: ssd...
# linha 98 nao tem face... m:DeepID | d: ssd
# running m:DeepFace | d: ssd...
# linha 0 nao tem face... m:DeepFace | d: ssd
# linha 1 nao tem face... m:DeepFace | d: ssd
# linha 2 nao tem face... m:DeepFace | d: ssd
# linha 3 nao tem face... m:DeepFace | d: ssd
# linha 4 nao tem face... m:DeepFace | d: ssd
# linha 5 nao tem face... m:DeepFace | d: ssd
# linha 6 nao tem face... m:DeepFace | d: ssd
# linha 7 nao tem face... m:DeepFace | d: ssd
# linha 8 nao tem face... m:DeepFace | d: ssd
# linha 9 nao tem face... m:DeepFace | d: ssd
# linha 10 nao tem face... m:DeepFace | d: ssd
# linha 11 nao tem face... m:DeepFace | d: ssd
# linha 12 nao tem face... m:DeepFace | d: ssd
# linha 13 nao tem face... m:DeepFace | d: ssd
# linha 14 nao tem face... m:DeepFace | d: ssd
# linha 15 nao tem face... m:DeepFace | d: ssd
# linha 16 nao tem face... m:DeepFace | d: ssd
# linha 17 nao tem face... m:DeepFace | d: ssd
# linha 18 nao tem face... m:DeepFace | d: ssd
# linha 19 nao tem face... m:DeepFace | d: ssd
# linha 20 nao tem face... m:DeepFace | d: ssd
# linha 21 nao tem face... m:DeepFace | d: ssd
# linha 22 nao tem face... m:DeepFace | d: ssd
# linha 23 nao tem face... m:DeepFace | d: ssd
# linha 24 nao tem face... m:DeepFace | d: ssd
# linha 25 nao tem face... m:DeepFace | d: ssd
# linha 26 nao tem face... m:DeepFace | d: ssd
# linha 27 nao tem face... m:DeepFace | d: ssd
# linha 28 nao tem face... m:DeepFace | d: ssd
# linha 29 nao tem face... m:DeepFace | d: ssd
# linha 30 nao tem face... m:DeepFace | d: ssd
# linha 31 nao tem face... m:DeepFace | d: ssd
# linha 32 nao tem face... m:DeepFace | d: ssd
# linha 33 nao tem face... m:DeepFace | d: ssd
# linha 34 nao tem face... m:DeepFace | d: ssd
# linha 35 nao tem face... m:DeepFace | d: ssd
# linha 36 nao tem face... m:DeepFace | d: ssd
# linha 37 nao tem face... m:DeepFace | d: ssd
# linha 38 nao tem face... m:DeepFace | d: ssd
# linha 39 nao tem face... m:DeepFace | d: ssd
# linha 40 nao tem face... m:DeepFace | d: ssd
# linha 41 nao tem face... m:DeepFace | d: ssd
# linha 42 nao tem face... m:DeepFace | d: ssd
# linha 43 nao tem face... m:DeepFace | d: ssd
# linha 44 nao tem face... m:DeepFace | d: ssd
# linha 45 nao tem face... m:DeepFace | d: ssd
# linha 46 nao tem face... m:DeepFace | d: ssd
# linha 47 nao tem face... m:DeepFace | d: ssd
# linha 48 nao tem face... m:DeepFace | d: ssd
# linha 49 nao tem face... m:DeepFace | d: ssd
# linha 50 nao tem face... m:DeepFace | d: ssd
# linha 51 nao tem face... m:DeepFace | d: ssd
# linha 52 nao tem face... m:DeepFace | d: ssd
# linha 53 nao tem face... m:DeepFace | d: ssd
# linha 54 nao tem face... m:DeepFace | d: ssd
# linha 55 nao tem face... m:DeepFace | d: ssd
# linha 56 nao tem face... m:DeepFace | d: ssd
# linha 57 nao tem face... m:DeepFace | d: ssd
# linha 58 nao tem face... m:DeepFace | d: ssd
# linha 59 nao tem face... m:DeepFace | d: ssd
# linha 60 nao tem face... m:DeepFace | d: ssd
# linha 61 nao tem face... m:DeepFace | d: ssd
# linha 62 nao tem face... m:DeepFace | d: ssd
# linha 63 nao tem face... m:DeepFace | d: ssd
# linha 64 nao tem face... m:DeepFace | d: ssd
# linha 65 nao tem face... m:DeepFace | d: ssd
# linha 66 nao tem face... m:DeepFace | d: ssd
# linha 67 nao tem face... m:DeepFace | d: ssd
# linha 68 nao tem face... m:DeepFace | d: ssd
# linha 69 nao tem face... m:DeepFace | d: ssd
# linha 70 nao tem face... m:DeepFace | d: ssd
# linha 71 nao tem face... m:DeepFace | d: ssd
# linha 72 nao tem face... m:DeepFace | d: ssd
# linha 73 nao tem face... m:DeepFace | d: ssd
# linha 74 nao tem face... m:DeepFace | d: ssd
# linha 75 nao tem face... m:DeepFace | d: ssd
# linha 76 nao tem face... m:DeepFace | d: ssd
# linha 77 nao tem face... m:DeepFace | d: ssd
# linha 78 nao tem face... m:DeepFace | d: ssd
# linha 79 nao tem face... m:DeepFace | d: ssd
# linha 80 nao tem face... m:DeepFace | d: ssd
# linha 81 nao tem face... m:DeepFace | d: ssd
# linha 82 nao tem face... m:DeepFace | d: ssd
# linha 83 nao tem face... m:DeepFace | d: ssd
# linha 84 nao tem face... m:DeepFace | d: ssd
# linha 85 nao tem face... m:DeepFace | d: ssd
# linha 86 nao tem face... m:DeepFace | d: ssd
# linha 87 nao tem face... m:DeepFace | d: ssd
# linha 88 nao tem face... m:DeepFace | d: ssd
# linha 89 nao tem face... m:DeepFace | d: ssd
# linha 90 nao tem face... m:DeepFace | d: ssd
# linha 91 nao tem face... m:DeepFace | d: ssd
# linha 92 nao tem face... m:DeepFace | d: ssd
# linha 93 nao tem face... m:DeepFace | d: ssd
# linha 94 nao tem face... m:DeepFace | d: ssd
# linha 95 nao tem face... m:DeepFace | d: ssd
# linha 96 nao tem face... m:DeepFace | d: ssd
# linha 97 nao tem face... m:DeepFace | d: ssd
# linha 98 nao tem face... m:DeepFace | d: ssd
# linha 99 nao tem face... m:DeepFace | d: ssd
# running m:GhostFaceNet | d: ssd...
# linha 98 nao tem face... m:GhostFaceNet | d: ssd
# running m:sFace | d: ssd...
# linha 0 nao tem face... m:sFace | d: ssd
# linha 1 nao tem face... m:sFace | d: ssd
# linha 2 nao tem face... m:sFace | d: ssd
# linha 3 nao tem face... m:sFace | d: ssd
# linha 4 nao tem face... m:sFace | d: ssd
# linha 5 nao tem face... m:sFace | d: ssd
# linha 6 nao tem face... m:sFace | d: ssd
# linha 7 nao tem face... m:sFace | d: ssd
# linha 8 nao tem face... m:sFace | d: ssd
# linha 9 nao tem face... m:sFace | d: ssd
# linha 10 nao tem face... m:sFace | d: ssd
# linha 11 nao tem face... m:sFace | d: ssd
# linha 12 nao tem face... m:sFace | d: ssd
# linha 13 nao tem face... m:sFace | d: ssd
# linha 14 nao tem face... m:sFace | d: ssd
# linha 15 nao tem face... m:sFace | d: ssd
# linha 16 nao tem face... m:sFace | d: ssd
# linha 17 nao tem face... m:sFace | d: ssd
# linha 18 nao tem face... m:sFace | d: ssd
# linha 19 nao tem face... m:sFace | d: ssd
# linha 20 nao tem face... m:sFace | d: ssd
# linha 21 nao tem face... m:sFace | d: ssd
# linha 22 nao tem face... m:sFace | d: ssd
# linha 23 nao tem face... m:sFace | d: ssd
# linha 24 nao tem face... m:sFace | d: ssd
# linha 25 nao tem face... m:sFace | d: ssd
# linha 26 nao tem face... m:sFace | d: ssd
# linha 27 nao tem face... m:sFace | d: ssd
# linha 28 nao tem face... m:sFace | d: ssd
# linha 29 nao tem face... m:sFace | d: ssd
# linha 30 nao tem face... m:sFace | d: ssd
# linha 31 nao tem face... m:sFace | d: ssd
# linha 32 nao tem face... m:sFace | d: ssd
# linha 33 nao tem face... m:sFace | d: ssd
# linha 34 nao tem face... m:sFace | d: ssd
# linha 35 nao tem face... m:sFace | d: ssd
# linha 36 nao tem face... m:sFace | d: ssd
# linha 37 nao tem face... m:sFace | d: ssd
# linha 38 nao tem face... m:sFace | d: ssd
# linha 39 nao tem face... m:sFace | d: ssd
# linha 40 nao tem face... m:sFace | d: ssd
# linha 41 nao tem face... m:sFace | d: ssd
# linha 42 nao tem face... m:sFace | d: ssd
# linha 43 nao tem face... m:sFace | d: ssd
# linha 44 nao tem face... m:sFace | d: ssd
# linha 45 nao tem face... m:sFace | d: ssd
# linha 46 nao tem face... m:sFace | d: ssd
# linha 47 nao tem face... m:sFace | d: ssd
# linha 48 nao tem face... m:sFace | d: ssd
# linha 49 nao tem face... m:sFace | d: ssd
# linha 50 nao tem face... m:sFace | d: ssd
# linha 51 nao tem face... m:sFace | d: ssd
# linha 52 nao tem face... m:sFace | d: ssd
# linha 53 nao tem face... m:sFace | d: ssd
# linha 54 nao tem face... m:sFace | d: ssd
# linha 55 nao tem face... m:sFace | d: ssd
# linha 56 nao tem face... m:sFace | d: ssd
# linha 57 nao tem face... m:sFace | d: ssd
# linha 58 nao tem face... m:sFace | d: ssd
# linha 59 nao tem face... m:sFace | d: ssd
# linha 60 nao tem face... m:sFace | d: ssd
# linha 61 nao tem face... m:sFace | d: ssd
# linha 62 nao tem face... m:sFace | d: ssd
# linha 63 nao tem face... m:sFace | d: ssd
# linha 64 nao tem face... m:sFace | d: ssd
# linha 65 nao tem face... m:sFace | d: ssd
# linha 66 nao tem face... m:sFace | d: ssd
# linha 67 nao tem face... m:sFace | d: ssd
# linha 68 nao tem face... m:sFace | d: ssd
# linha 69 nao tem face... m:sFace | d: ssd
# linha 70 nao tem face... m:sFace | d: ssd
# linha 71 nao tem face... m:sFace | d: ssd
# linha 72 nao tem face... m:sFace | d: ssd
# linha 73 nao tem face... m:sFace | d: ssd
# linha 74 nao tem face... m:sFace | d: ssd
# linha 75 nao tem face... m:sFace | d: ssd
# linha 76 nao tem face... m:sFace | d: ssd
# linha 77 nao tem face... m:sFace | d: ssd
# linha 78 nao tem face... m:sFace | d: ssd
# linha 79 nao tem face... m:sFace | d: ssd
# linha 80 nao tem face... m:sFace | d: ssd
# linha 81 nao tem face... m:sFace | d: ssd
# linha 82 nao tem face... m:sFace | d: ssd
# linha 83 nao tem face... m:sFace | d: ssd
# linha 84 nao tem face... m:sFace | d: ssd
# linha 85 nao tem face... m:sFace | d: ssd
# linha 86 nao tem face... m:sFace | d: ssd
# linha 87 nao tem face... m:sFace | d: ssd
# linha 88 nao tem face... m:sFace | d: ssd
# linha 89 nao tem face... m:sFace | d: ssd
# linha 90 nao tem face... m:sFace | d: ssd
# linha 91 nao tem face... m:sFace | d: ssd
# linha 92 nao tem face... m:sFace | d: ssd
# linha 93 nao tem face... m:sFace | d: ssd
# linha 94 nao tem face... m:sFace | d: ssd
# linha 95 nao tem face... m:sFace | d: ssd
# linha 96 nao tem face... m:sFace | d: ssd
# linha 97 nao tem face... m:sFace | d: ssd
# linha 98 nao tem face... m:sFace | d: ssd
# linha 99 nao tem face... m:sFace | d: ssd
# running m:Dlib | d: dlib...
# linha 0 nao tem face... m:Dlib | d: dlib
# linha 1 nao tem face... m:Dlib | d: dlib
# linha 2 nao tem face... m:Dlib | d: dlib
# linha 3 nao tem face... m:Dlib | d: dlib
# linha 4 nao tem face... m:Dlib | d: dlib
# linha 5 nao tem face... m:Dlib | d: dlib
# linha 6 nao tem face... m:Dlib | d: dlib
# linha 7 nao tem face... m:Dlib | d: dlib
# linha 8 nao tem face... m:Dlib | d: dlib
# linha 9 nao tem face... m:Dlib | d: dlib
# linha 10 nao tem face... m:Dlib | d: dlib
# linha 11 nao tem face... m:Dlib | d: dlib
# linha 12 nao tem face... m:Dlib | d: dlib
# linha 13 nao tem face... m:Dlib | d: dlib
# linha 14 nao tem face... m:Dlib | d: dlib
# linha 15 nao tem face... m:Dlib | d: dlib
# linha 16 nao tem face... m:Dlib | d: dlib
# linha 17 nao tem face... m:Dlib | d: dlib
# linha 18 nao tem face... m:Dlib | d: dlib
# linha 19 nao tem face... m:Dlib | d: dlib
# linha 20 nao tem face... m:Dlib | d: dlib
# linha 21 nao tem face... m:Dlib | d: dlib
# linha 22 nao tem face... m:Dlib | d: dlib
# linha 23 nao tem face... m:Dlib | d: dlib
# linha 24 nao tem face... m:Dlib | d: dlib
# linha 25 nao tem face... m:Dlib | d: dlib
# linha 26 nao tem face... m:Dlib | d: dlib
# linha 27 nao tem face... m:Dlib | d: dlib
# linha 28 nao tem face... m:Dlib | d: dlib
# linha 29 nao tem face... m:Dlib | d: dlib
# linha 30 nao tem face... m:Dlib | d: dlib
# linha 31 nao tem face... m:Dlib | d: dlib
# linha 32 nao tem face... m:Dlib | d: dlib
# linha 33 nao tem face... m:Dlib | d: dlib
# linha 34 nao tem face... m:Dlib | d: dlib
# linha 35 nao tem face... m:Dlib | d: dlib
# linha 36 nao tem face... m:Dlib | d: dlib
# linha 37 nao tem face... m:Dlib | d: dlib
# linha 38 nao tem face... m:Dlib | d: dlib
# linha 39 nao tem face... m:Dlib | d: dlib
# linha 40 nao tem face... m:Dlib | d: dlib
# linha 41 nao tem face... m:Dlib | d: dlib
# linha 42 nao tem face... m:Dlib | d: dlib
# linha 43 nao tem face... m:Dlib | d: dlib
# linha 44 nao tem face... m:Dlib | d: dlib
# linha 45 nao tem face... m:Dlib | d: dlib
# linha 46 nao tem face... m:Dlib | d: dlib
# linha 47 nao tem face... m:Dlib | d: dlib
# linha 48 nao tem face... m:Dlib | d: dlib
# linha 49 nao tem face... m:Dlib | d: dlib
# linha 50 nao tem face... m:Dlib | d: dlib
# linha 51 nao tem face... m:Dlib | d: dlib
# linha 52 nao tem face... m:Dlib | d: dlib
# linha 53 nao tem face... m:Dlib | d: dlib
# linha 54 nao tem face... m:Dlib | d: dlib
# linha 55 nao tem face... m:Dlib | d: dlib
# linha 56 nao tem face... m:Dlib | d: dlib
# linha 57 nao tem face... m:Dlib | d: dlib
# linha 58 nao tem face... m:Dlib | d: dlib
# linha 59 nao tem face... m:Dlib | d: dlib
# linha 60 nao tem face... m:Dlib | d: dlib
# linha 61 nao tem face... m:Dlib | d: dlib
# linha 62 nao tem face... m:Dlib | d: dlib
# linha 63 nao tem face... m:Dlib | d: dlib
# linha 64 nao tem face... m:Dlib | d: dlib
# linha 65 nao tem face... m:Dlib | d: dlib
# linha 66 nao tem face... m:Dlib | d: dlib
# linha 67 nao tem face... m:Dlib | d: dlib
# linha 68 nao tem face... m:Dlib | d: dlib
# linha 69 nao tem face... m:Dlib | d: dlib
# linha 70 nao tem face... m:Dlib | d: dlib
# linha 71 nao tem face... m:Dlib | d: dlib
# linha 72 nao tem face... m:Dlib | d: dlib
# linha 73 nao tem face... m:Dlib | d: dlib
# linha 74 nao tem face... m:Dlib | d: dlib
# linha 75 nao tem face... m:Dlib | d: dlib
# linha 76 nao tem face... m:Dlib | d: dlib
# linha 77 nao tem face... m:Dlib | d: dlib
# linha 78 nao tem face... m:Dlib | d: dlib
# linha 79 nao tem face... m:Dlib | d: dlib
# linha 80 nao tem face... m:Dlib | d: dlib
# linha 81 nao tem face... m:Dlib | d: dlib
# linha 82 nao tem face... m:Dlib | d: dlib
# linha 83 nao tem face... m:Dlib | d: dlib
# linha 84 nao tem face... m:Dlib | d: dlib
# linha 85 nao tem face... m:Dlib | d: dlib
# linha 86 nao tem face... m:Dlib | d: dlib
# linha 87 nao tem face... m:Dlib | d: dlib
# linha 88 nao tem face... m:Dlib | d: dlib
# linha 89 nao tem face... m:Dlib | d: dlib
# linha 90 nao tem face... m:Dlib | d: dlib
# linha 91 nao tem face... m:Dlib | d: dlib
# linha 92 nao tem face... m:Dlib | d: dlib
# linha 93 nao tem face... m:Dlib | d: dlib
# linha 94 nao tem face... m:Dlib | d: dlib
# linha 95 nao tem face... m:Dlib | d: dlib
# linha 96 nao tem face... m:Dlib | d: dlib
# linha 97 nao tem face... m:Dlib | d: dlib
# linha 98 nao tem face... m:Dlib | d: dlib
# linha 99 nao tem face... m:Dlib | d: dlib
# running m:Facenet512 | d: dlib...
# linha 0 nao tem face... m:Facenet512 | d: dlib
# linha 1 nao tem face... m:Facenet512 | d: dlib
# linha 2 nao tem face... m:Facenet512 | d: dlib
# linha 3 nao tem face... m:Facenet512 | d: dlib
# linha 4 nao tem face... m:Facenet512 | d: dlib
# linha 5 nao tem face... m:Facenet512 | d: dlib
# linha 6 nao tem face... m:Facenet512 | d: dlib
# linha 7 nao tem face... m:Facenet512 | d: dlib
# linha 8 nao tem face... m:Facenet512 | d: dlib
# linha 9 nao tem face... m:Facenet512 | d: dlib
# linha 10 nao tem face... m:Facenet512 | d: dlib
# linha 11 nao tem face... m:Facenet512 | d: dlib
# linha 12 nao tem face... m:Facenet512 | d: dlib
# linha 13 nao tem face... m:Facenet512 | d: dlib
# linha 14 nao tem face... m:Facenet512 | d: dlib
# linha 15 nao tem face... m:Facenet512 | d: dlib
# linha 16 nao tem face... m:Facenet512 | d: dlib
# linha 17 nao tem face... m:Facenet512 | d: dlib
# linha 18 nao tem face... m:Facenet512 | d: dlib
# linha 19 nao tem face... m:Facenet512 | d: dlib
# linha 20 nao tem face... m:Facenet512 | d: dlib
# linha 21 nao tem face... m:Facenet512 | d: dlib
# linha 22 nao tem face... m:Facenet512 | d: dlib
# linha 23 nao tem face... m:Facenet512 | d: dlib
# linha 24 nao tem face... m:Facenet512 | d: dlib
# linha 25 nao tem face... m:Facenet512 | d: dlib
# linha 26 nao tem face... m:Facenet512 | d: dlib
# linha 27 nao tem face... m:Facenet512 | d: dlib
# linha 28 nao tem face... m:Facenet512 | d: dlib
# linha 29 nao tem face... m:Facenet512 | d: dlib
# linha 30 nao tem face... m:Facenet512 | d: dlib
# linha 31 nao tem face... m:Facenet512 | d: dlib
# linha 32 nao tem face... m:Facenet512 | d: dlib
# linha 33 nao tem face... m:Facenet512 | d: dlib
# linha 34 nao tem face... m:Facenet512 | d: dlib
# linha 35 nao tem face... m:Facenet512 | d: dlib
# linha 36 nao tem face... m:Facenet512 | d: dlib
# linha 37 nao tem face... m:Facenet512 | d: dlib
# linha 38 nao tem face... m:Facenet512 | d: dlib
# linha 39 nao tem face... m:Facenet512 | d: dlib
# linha 40 nao tem face... m:Facenet512 | d: dlib
# linha 41 nao tem face... m:Facenet512 | d: dlib
# linha 42 nao tem face... m:Facenet512 | d: dlib
# linha 43 nao tem face... m:Facenet512 | d: dlib
# linha 44 nao tem face... m:Facenet512 | d: dlib
# linha 45 nao tem face... m:Facenet512 | d: dlib
# linha 46 nao tem face... m:Facenet512 | d: dlib
# linha 47 nao tem face... m:Facenet512 | d: dlib
# linha 48 nao tem face... m:Facenet512 | d: dlib
# linha 49 nao tem face... m:Facenet512 | d: dlib
# linha 50 nao tem face... m:Facenet512 | d: dlib
# linha 51 nao tem face... m:Facenet512 | d: dlib
# linha 52 nao tem face... m:Facenet512 | d: dlib
# linha 53 nao tem face... m:Facenet512 | d: dlib
# linha 54 nao tem face... m:Facenet512 | d: dlib
# linha 55 nao tem face... m:Facenet512 | d: dlib
# linha 56 nao tem face... m:Facenet512 | d: dlib
# linha 57 nao tem face... m:Facenet512 | d: dlib
# linha 58 nao tem face... m:Facenet512 | d: dlib
# linha 59 nao tem face... m:Facenet512 | d: dlib
# linha 60 nao tem face... m:Facenet512 | d: dlib
# linha 61 nao tem face... m:Facenet512 | d: dlib
# linha 62 nao tem face... m:Facenet512 | d: dlib
# linha 63 nao tem face... m:Facenet512 | d: dlib
# linha 64 nao tem face... m:Facenet512 | d: dlib
# linha 65 nao tem face... m:Facenet512 | d: dlib
# linha 66 nao tem face... m:Facenet512 | d: dlib
# linha 67 nao tem face... m:Facenet512 | d: dlib
# linha 68 nao tem face... m:Facenet512 | d: dlib
# linha 69 nao tem face... m:Facenet512 | d: dlib
# linha 70 nao tem face... m:Facenet512 | d: dlib
# linha 71 nao tem face... m:Facenet512 | d: dlib
# linha 72 nao tem face... m:Facenet512 | d: dlib
# linha 73 nao tem face... m:Facenet512 | d: dlib
# linha 74 nao tem face... m:Facenet512 | d: dlib
# linha 75 nao tem face... m:Facenet512 | d: dlib
# linha 76 nao tem face... m:Facenet512 | d: dlib
# linha 77 nao tem face... m:Facenet512 | d: dlib
# linha 78 nao tem face... m:Facenet512 | d: dlib
# linha 79 nao tem face... m:Facenet512 | d: dlib
# linha 80 nao tem face... m:Facenet512 | d: dlib
# linha 81 nao tem face... m:Facenet512 | d: dlib
# linha 82 nao tem face... m:Facenet512 | d: dlib
# linha 83 nao tem face... m:Facenet512 | d: dlib
# linha 84 nao tem face... m:Facenet512 | d: dlib
# linha 85 nao tem face... m:Facenet512 | d: dlib
# linha 86 nao tem face... m:Facenet512 | d: dlib
# linha 87 nao tem face... m:Facenet512 | d: dlib
# linha 88 nao tem face... m:Facenet512 | d: dlib
# linha 89 nao tem face... m:Facenet512 | d: dlib
# linha 90 nao tem face... m:Facenet512 | d: dlib
# linha 91 nao tem face... m:Facenet512 | d: dlib
# linha 92 nao tem face... m:Facenet512 | d: dlib
# linha 93 nao tem face... m:Facenet512 | d: dlib
# linha 94 nao tem face... m:Facenet512 | d: dlib
# linha 95 nao tem face... m:Facenet512 | d: dlib
# linha 96 nao tem face... m:Facenet512 | d: dlib
# linha 97 nao tem face... m:Facenet512 | d: dlib
# linha 98 nao tem face... m:Facenet512 | d: dlib
# linha 99 nao tem face... m:Facenet512 | d: dlib
# running m:Facenet | d: dlib...
# linha 0 nao tem face... m:Facenet | d: dlib
# linha 1 nao tem face... m:Facenet | d: dlib
# linha 2 nao tem face... m:Facenet | d: dlib
# linha 3 nao tem face... m:Facenet | d: dlib
# linha 4 nao tem face... m:Facenet | d: dlib
# linha 5 nao tem face... m:Facenet | d: dlib
# linha 6 nao tem face... m:Facenet | d: dlib
# linha 7 nao tem face... m:Facenet | d: dlib
# linha 8 nao tem face... m:Facenet | d: dlib
# linha 9 nao tem face... m:Facenet | d: dlib
# linha 10 nao tem face... m:Facenet | d: dlib
# linha 11 nao tem face... m:Facenet | d: dlib
# linha 12 nao tem face... m:Facenet | d: dlib
# linha 13 nao tem face... m:Facenet | d: dlib
# linha 14 nao tem face... m:Facenet | d: dlib
# linha 15 nao tem face... m:Facenet | d: dlib
# linha 16 nao tem face... m:Facenet | d: dlib
# linha 17 nao tem face... m:Facenet | d: dlib
# linha 18 nao tem face... m:Facenet | d: dlib
# linha 19 nao tem face... m:Facenet | d: dlib
# linha 20 nao tem face... m:Facenet | d: dlib
# linha 21 nao tem face... m:Facenet | d: dlib
# linha 22 nao tem face... m:Facenet | d: dlib
# linha 23 nao tem face... m:Facenet | d: dlib
# linha 24 nao tem face... m:Facenet | d: dlib
# linha 25 nao tem face... m:Facenet | d: dlib
# linha 26 nao tem face... m:Facenet | d: dlib
# linha 27 nao tem face... m:Facenet | d: dlib
# linha 28 nao tem face... m:Facenet | d: dlib
# linha 29 nao tem face... m:Facenet | d: dlib
# linha 30 nao tem face... m:Facenet | d: dlib
# linha 31 nao tem face... m:Facenet | d: dlib
# linha 32 nao tem face... m:Facenet | d: dlib
# linha 33 nao tem face... m:Facenet | d: dlib
# linha 34 nao tem face... m:Facenet | d: dlib
# linha 35 nao tem face... m:Facenet | d: dlib
# linha 36 nao tem face... m:Facenet | d: dlib
# linha 37 nao tem face... m:Facenet | d: dlib
# linha 38 nao tem face... m:Facenet | d: dlib
# linha 39 nao tem face... m:Facenet | d: dlib
# linha 40 nao tem face... m:Facenet | d: dlib
# linha 41 nao tem face... m:Facenet | d: dlib
# linha 42 nao tem face... m:Facenet | d: dlib
# linha 43 nao tem face... m:Facenet | d: dlib
# linha 44 nao tem face... m:Facenet | d: dlib
# linha 45 nao tem face... m:Facenet | d: dlib
# linha 46 nao tem face... m:Facenet | d: dlib
# linha 47 nao tem face... m:Facenet | d: dlib
# linha 48 nao tem face... m:Facenet | d: dlib
# linha 49 nao tem face... m:Facenet | d: dlib
# linha 50 nao tem face... m:Facenet | d: dlib
# linha 51 nao tem face... m:Facenet | d: dlib
# linha 52 nao tem face... m:Facenet | d: dlib
# linha 53 nao tem face... m:Facenet | d: dlib
# linha 54 nao tem face... m:Facenet | d: dlib
# linha 55 nao tem face... m:Facenet | d: dlib
# linha 56 nao tem face... m:Facenet | d: dlib
# linha 57 nao tem face... m:Facenet | d: dlib
# linha 58 nao tem face... m:Facenet | d: dlib
# linha 59 nao tem face... m:Facenet | d: dlib
# linha 60 nao tem face... m:Facenet | d: dlib
# linha 61 nao tem face... m:Facenet | d: dlib
# linha 62 nao tem face... m:Facenet | d: dlib
# linha 63 nao tem face... m:Facenet | d: dlib
# linha 64 nao tem face... m:Facenet | d: dlib
# linha 65 nao tem face... m:Facenet | d: dlib
# linha 66 nao tem face... m:Facenet | d: dlib
# linha 67 nao tem face... m:Facenet | d: dlib
# linha 68 nao tem face... m:Facenet | d: dlib
# linha 69 nao tem face... m:Facenet | d: dlib
# linha 70 nao tem face... m:Facenet | d: dlib
# linha 71 nao tem face... m:Facenet | d: dlib
# linha 72 nao tem face... m:Facenet | d: dlib
# linha 73 nao tem face... m:Facenet | d: dlib
# linha 74 nao tem face... m:Facenet | d: dlib
# linha 75 nao tem face... m:Facenet | d: dlib
# linha 76 nao tem face... m:Facenet | d: dlib
# linha 77 nao tem face... m:Facenet | d: dlib
# linha 78 nao tem face... m:Facenet | d: dlib
# linha 79 nao tem face... m:Facenet | d: dlib
# linha 80 nao tem face... m:Facenet | d: dlib
# linha 81 nao tem face... m:Facenet | d: dlib
# linha 82 nao tem face... m:Facenet | d: dlib
# linha 83 nao tem face... m:Facenet | d: dlib
# linha 84 nao tem face... m:Facenet | d: dlib
# linha 85 nao tem face... m:Facenet | d: dlib
# linha 86 nao tem face... m:Facenet | d: dlib
# linha 87 nao tem face... m:Facenet | d: dlib
# linha 88 nao tem face... m:Facenet | d: dlib
# linha 89 nao tem face... m:Facenet | d: dlib
# linha 90 nao tem face... m:Facenet | d: dlib
# linha 91 nao tem face... m:Facenet | d: dlib
# linha 92 nao tem face... m:Facenet | d: dlib
# linha 93 nao tem face... m:Facenet | d: dlib
# linha 94 nao tem face... m:Facenet | d: dlib
# linha 95 nao tem face... m:Facenet | d: dlib
# linha 96 nao tem face... m:Facenet | d: dlib
# linha 97 nao tem face... m:Facenet | d: dlib
# linha 98 nao tem face... m:Facenet | d: dlib
# linha 99 nao tem face... m:Facenet | d: dlib
# running m:ArcFace | d: dlib...
# linha 0 nao tem face... m:ArcFace | d: dlib
# linha 1 nao tem face... m:ArcFace | d: dlib
# linha 2 nao tem face... m:ArcFace | d: dlib
# linha 3 nao tem face... m:ArcFace | d: dlib
# linha 4 nao tem face... m:ArcFace | d: dlib
# linha 5 nao tem face... m:ArcFace | d: dlib
# linha 6 nao tem face... m:ArcFace | d: dlib
# linha 7 nao tem face... m:ArcFace | d: dlib
# linha 8 nao tem face... m:ArcFace | d: dlib
# linha 9 nao tem face... m:ArcFace | d: dlib
# linha 10 nao tem face... m:ArcFace | d: dlib
# linha 11 nao tem face... m:ArcFace | d: dlib
# linha 12 nao tem face... m:ArcFace | d: dlib
# linha 13 nao tem face... m:ArcFace | d: dlib
# linha 14 nao tem face... m:ArcFace | d: dlib
# linha 15 nao tem face... m:ArcFace | d: dlib
# linha 16 nao tem face... m:ArcFace | d: dlib
# linha 17 nao tem face... m:ArcFace | d: dlib
# linha 18 nao tem face... m:ArcFace | d: dlib
# linha 19 nao tem face... m:ArcFace | d: dlib
# linha 20 nao tem face... m:ArcFace | d: dlib
# linha 21 nao tem face... m:ArcFace | d: dlib
# linha 22 nao tem face... m:ArcFace | d: dlib
# linha 23 nao tem face... m:ArcFace | d: dlib
# linha 24 nao tem face... m:ArcFace | d: dlib
# linha 25 nao tem face... m:ArcFace | d: dlib
# linha 26 nao tem face... m:ArcFace | d: dlib
# linha 27 nao tem face... m:ArcFace | d: dlib
# linha 28 nao tem face... m:ArcFace | d: dlib
# linha 29 nao tem face... m:ArcFace | d: dlib
# linha 30 nao tem face... m:ArcFace | d: dlib
# linha 31 nao tem face... m:ArcFace | d: dlib
# linha 32 nao tem face... m:ArcFace | d: dlib
# linha 33 nao tem face... m:ArcFace | d: dlib
# linha 34 nao tem face... m:ArcFace | d: dlib
# linha 35 nao tem face... m:ArcFace | d: dlib
# linha 36 nao tem face... m:ArcFace | d: dlib
# linha 37 nao tem face... m:ArcFace | d: dlib
# linha 38 nao tem face... m:ArcFace | d: dlib
# linha 39 nao tem face... m:ArcFace | d: dlib
# linha 40 nao tem face... m:ArcFace | d: dlib
# linha 41 nao tem face... m:ArcFace | d: dlib
# linha 42 nao tem face... m:ArcFace | d: dlib
# linha 43 nao tem face... m:ArcFace | d: dlib
# linha 44 nao tem face... m:ArcFace | d: dlib
# linha 45 nao tem face... m:ArcFace | d: dlib
# linha 46 nao tem face... m:ArcFace | d: dlib
# linha 47 nao tem face... m:ArcFace | d: dlib
# linha 48 nao tem face... m:ArcFace | d: dlib
# linha 49 nao tem face... m:ArcFace | d: dlib
# linha 50 nao tem face... m:ArcFace | d: dlib
# linha 51 nao tem face... m:ArcFace | d: dlib
# linha 52 nao tem face... m:ArcFace | d: dlib
# linha 53 nao tem face... m:ArcFace | d: dlib
# linha 54 nao tem face... m:ArcFace | d: dlib
# linha 55 nao tem face... m:ArcFace | d: dlib
# linha 56 nao tem face... m:ArcFace | d: dlib
# linha 57 nao tem face... m:ArcFace | d: dlib
# linha 58 nao tem face... m:ArcFace | d: dlib
# linha 59 nao tem face... m:ArcFace | d: dlib
# linha 60 nao tem face... m:ArcFace | d: dlib
# linha 61 nao tem face... m:ArcFace | d: dlib
# linha 62 nao tem face... m:ArcFace | d: dlib
# linha 63 nao tem face... m:ArcFace | d: dlib
# linha 64 nao tem face... m:ArcFace | d: dlib
# linha 65 nao tem face... m:ArcFace | d: dlib
# linha 66 nao tem face... m:ArcFace | d: dlib
# linha 67 nao tem face... m:ArcFace | d: dlib
# linha 68 nao tem face... m:ArcFace | d: dlib
# linha 69 nao tem face... m:ArcFace | d: dlib
# linha 70 nao tem face... m:ArcFace | d: dlib
# linha 71 nao tem face... m:ArcFace | d: dlib
# linha 72 nao tem face... m:ArcFace | d: dlib
# linha 73 nao tem face... m:ArcFace | d: dlib
# linha 74 nao tem face... m:ArcFace | d: dlib
# linha 75 nao tem face... m:ArcFace | d: dlib
# linha 76 nao tem face... m:ArcFace | d: dlib
# linha 77 nao tem face... m:ArcFace | d: dlib
# linha 78 nao tem face... m:ArcFace | d: dlib
# linha 79 nao tem face... m:ArcFace | d: dlib
# linha 80 nao tem face... m:ArcFace | d: dlib
# linha 81 nao tem face... m:ArcFace | d: dlib
# linha 82 nao tem face... m:ArcFace | d: dlib
# linha 83 nao tem face... m:ArcFace | d: dlib
# linha 84 nao tem face... m:ArcFace | d: dlib
# linha 85 nao tem face... m:ArcFace | d: dlib
# linha 86 nao tem face... m:ArcFace | d: dlib
# linha 87 nao tem face... m:ArcFace | d: dlib
# linha 88 nao tem face... m:ArcFace | d: dlib
# linha 89 nao tem face... m:ArcFace | d: dlib
# linha 90 nao tem face... m:ArcFace | d: dlib
# linha 91 nao tem face... m:ArcFace | d: dlib
# linha 92 nao tem face... m:ArcFace | d: dlib
# linha 93 nao tem face... m:ArcFace | d: dlib
# linha 94 nao tem face... m:ArcFace | d: dlib
# linha 95 nao tem face... m:ArcFace | d: dlib
# linha 96 nao tem face... m:ArcFace | d: dlib
# linha 97 nao tem face... m:ArcFace | d: dlib
# linha 98 nao tem face... m:ArcFace | d: dlib
# linha 99 nao tem face... m:ArcFace | d: dlib
# running m:OpenFace | d: dlib...
# linha 0 nao tem face... m:OpenFace | d: dlib
# linha 1 nao tem face... m:OpenFace | d: dlib
# linha 2 nao tem face... m:OpenFace | d: dlib
# linha 3 nao tem face... m:OpenFace | d: dlib
# ...
# linha 90 nao tem face... m:DeepID | d: fastmtcnn
# linha 91 nao tem face... m:DeepID | d: fastmtcnn
# linha 92 nao tem face... m:DeepID | d: fastmtcnn
# linha 93 nao tem face... m:DeepID | d: fastmtcnn
# linha 94 nao tem face... m:DeepID | d: fastmtcnn
# linha 95 nao tem face... m:DeepID | d: fastmtcnn
# linha 96 nao tem face... m:DeepID | d: fastmtcnn
# linha 97 nao tem face... m:DeepID | d: fastmtcnn
# linha 98 nao tem face... m:DeepID | d: fastmtcnn
# linha 99 nao tem face... m:DeepID | d: fastmtcnn
# running m:DeepFace | d: fastmtcnn...
# linha 0 nao tem face... m:DeepFace | d: fastmtcnn
# linha 1 nao tem face... m:DeepFace | d: fastmtcnn
# linha 2 nao tem face... m:DeepFace | d: fastmtcnn
# linha 3 nao tem face... m:DeepFace | d: fastmtcnn
# linha 4 nao tem face... m:DeepFace | d: fastmtcnn
# linha 5 nao tem face... m:DeepFace | d: fastmtcnn
# linha 6 nao tem face... m:DeepFace | d: fastmtcnn
# linha 7 nao tem face... m:DeepFace | d: fastmtcnn
# linha 8 nao tem face... m:DeepFace | d: fastmtcnn
# linha 9 nao tem face... m:DeepFace | d: fastmtcnn
# linha 10 nao tem face... m:DeepFace | d: fastmtcnn
# linha 11 nao tem face... m:DeepFace | d: fastmtcnn
# linha 12 nao tem face... m:DeepFace | d: fastmtcnn
# linha 13 nao tem face... m:DeepFace | d: fastmtcnn
# linha 14 nao tem face... m:DeepFace | d: fastmtcnn
# linha 15 nao tem face... m:DeepFace | d: fastmtcnn
# linha 16 nao tem face... m:DeepFace | d: fastmtcnn
# linha 17 nao tem face... m:DeepFace | d: fastmtcnn
# linha 18 nao tem face... m:DeepFace | d: fastmtcnn
# linha 19 nao tem face... m:DeepFace | d: fastmtcnn
# linha 20 nao tem face... m:DeepFace | d: fastmtcnn
# linha 21 nao tem face... m:DeepFace | d: fastmtcnn
# linha 22 nao tem face... m:DeepFace | d: fastmtcnn
# linha 23 nao tem face... m:DeepFace | d: fastmtcnn
# linha 24 nao tem face... m:DeepFace | d: fastmtcnn
# linha 25 nao tem face... m:DeepFace | d: fastmtcnn
# linha 26 nao tem face... m:DeepFace | d: fastmtcnn
# linha 27 nao tem face... m:DeepFace | d: fastmtcnn
# linha 28 nao tem face... m:DeepFace | d: fastmtcnn
# linha 29 nao tem face... m:DeepFace | d: fastmtcnn
# linha 30 nao tem face... m:DeepFace | d: fastmtcnn
# linha 31 nao tem face... m:DeepFace | d: fastmtcnn
# linha 32 nao tem face... m:DeepFace | d: fastmtcnn
# linha 33 nao tem face... m:DeepFace | d: fastmtcnn
# linha 34 nao tem face... m:DeepFace | d: fastmtcnn
# linha 35 nao tem face... m:DeepFace | d: fastmtcnn
# linha 36 nao tem face... m:DeepFace | d: fastmtcnn
# linha 37 nao tem face... m:DeepFace | d: fastmtcnn
# linha 38 nao tem face... m:DeepFace | d: fastmtcnn
# linha 39 nao tem face... m:DeepFace | d: fastmtcnn
# linha 40 nao tem face... m:DeepFace | d: fastmtcnn
# linha 41 nao tem face... m:DeepFace | d: fastmtcnn
# linha 42 nao tem face... m:DeepFace | d: fastmtcnn
# linha 43 nao tem face... m:DeepFace | d: fastmtcnn
# linha 44 nao tem face... m:DeepFace | d: fastmtcnn
# linha 45 nao tem face... m:DeepFace | d: fastmtcnn
# linha 46 nao tem face... m:DeepFace | d: fastmtcnn
# linha 47 nao tem face... m:DeepFace | d: fastmtcnn
# linha 48 nao tem face... m:DeepFace | d: fastmtcnn
# linha 49 nao tem face... m:DeepFace | d: fastmtcnn
# linha 50 nao tem face... m:DeepFace | d: fastmtcnn
# linha 51 nao tem face... m:DeepFace | d: fastmtcnn
# linha 52 nao tem face... m:DeepFace | d: fastmtcnn
# linha 53 nao tem face... m:DeepFace | d: fastmtcnn
# linha 54 nao tem face... m:DeepFace | d: fastmtcnn
# linha 55 nao tem face... m:DeepFace | d: fastmtcnn
# linha 56 nao tem face... m:DeepFace | d: fastmtcnn
# linha 57 nao tem face... m:DeepFace | d: fastmtcnn
# linha 58 nao tem face... m:DeepFace | d: fastmtcnn
# linha 59 nao tem face... m:DeepFace | d: fastmtcnn
# linha 60 nao tem face... m:DeepFace | d: fastmtcnn
# linha 61 nao tem face... m:DeepFace | d: fastmtcnn
# linha 62 nao tem face... m:DeepFace | d: fastmtcnn
# linha 63 nao tem face... m:DeepFace | d: fastmtcnn
# linha 64 nao tem face... m:DeepFace | d: fastmtcnn
# linha 65 nao tem face... m:DeepFace | d: fastmtcnn
# linha 66 nao tem face... m:DeepFace | d: fastmtcnn
# linha 67 nao tem face... m:DeepFace | d: fastmtcnn
# linha 68 nao tem face... m:DeepFace | d: fastmtcnn
# linha 69 nao tem face... m:DeepFace | d: fastmtcnn
# linha 70 nao tem face... m:DeepFace | d: fastmtcnn
# linha 71 nao tem face... m:DeepFace | d: fastmtcnn
# linha 72 nao tem face... m:DeepFace | d: fastmtcnn
# linha 73 nao tem face... m:DeepFace | d: fastmtcnn
# linha 74 nao tem face... m:DeepFace | d: fastmtcnn
# linha 75 nao tem face... m:DeepFace | d: fastmtcnn
# linha 76 nao tem face... m:DeepFace | d: fastmtcnn
# linha 77 nao tem face... m:DeepFace | d: fastmtcnn
# linha 78 nao tem face... m:DeepFace | d: fastmtcnn
# linha 79 nao tem face... m:DeepFace | d: fastmtcnn
# linha 80 nao tem face... m:DeepFace | d: fastmtcnn
# linha 81 nao tem face... m:DeepFace | d: fastmtcnn
# linha 82 nao tem face... m:DeepFace | d: fastmtcnn
# linha 83 nao tem face... m:DeepFace | d: fastmtcnn
# linha 84 nao tem face... m:DeepFace | d: fastmtcnn
# linha 85 nao tem face... m:DeepFace | d: fastmtcnn
# linha 86 nao tem face... m:DeepFace | d: fastmtcnn
# linha 87 nao tem face... m:DeepFace | d: fastmtcnn
# linha 88 nao tem face... m:DeepFace | d: fastmtcnn
# linha 89 nao tem face... m:DeepFace | d: fastmtcnn
# linha 90 nao tem face... m:DeepFace | d: fastmtcnn
# linha 91 nao tem face... m:DeepFace | d: fastmtcnn
# linha 92 nao tem face... m:DeepFace | d: fastmtcnn
# linha 93 nao tem face... m:DeepFace | d: fastmtcnn
# linha 94 nao tem face... m:DeepFace | d: fastmtcnn
# linha 95 nao tem face... m:DeepFace | d: fastmtcnn
# linha 96 nao tem face... m:DeepFace | d: fastmtcnn
# linha 97 nao tem face... m:DeepFace | d: fastmtcnn
# linha 98 nao tem face... m:DeepFace | d: fastmtcnn
# linha 99 nao tem face... m:DeepFace | d: fastmtcnn
# running m:GhostFaceNet | d: fastmtcnn...
# linha 0 nao tem face... m:GhostFaceNet | d: fastmtcnn
# linha 1 nao tem face... m:GhostFaceNet | d: fastmtcnn
# linha 2 nao tem face... m:GhostFaceNet | d: fastmtcnn
# linha 3 nao tem face... m:GhostFaceNet | d: fastmtcnn
# linha 4 nao tem face... m:GhostFaceNet | d: fastmtcnn
# linha 5 nao tem face... m:GhostFaceNet | d: fastmtcnn
# linha 6 nao tem face... m:GhostFaceNet | d: fastmtcnn
# linha 7 nao tem face... m:GhostFaceNet | d: fastmtcnn
# linha 8 nao tem face... m:GhostFaceNet | d: fastmtcnn
# linha 9 nao tem face... m:GhostFaceNet | d: fastmtcnn
# linha 10 nao tem face... m:GhostFaceNet | d: fastmtcnn
# linha 11 nao tem face... m:GhostFaceNet | d: fastmtcnn
# linha 12 nao tem face... m:GhostFaceNet | d: fastmtcnn
# linha 13 nao tem face... m:GhostFaceNet | d: fastmtcnn
# linha 14 nao tem face... m:GhostFaceNet | d: fastmtcnn
# linha 15 nao tem face... m:GhostFaceNet | d: fastmtcnn
# linha 16 nao tem face... m:GhostFaceNet | d: fastmtcnn
# linha 17 nao tem face... m:GhostFaceNet | d: fastmtcnn
# linha 18 nao tem face... m:GhostFaceNet | d: fastmtcnn
# linha 19 nao tem face... m:GhostFaceNet | d: fastmtcnn
# linha 20 nao tem face... m:GhostFaceNet | d: fastmtcnn
# linha 21 nao tem face... m:GhostFaceNet | d: fastmtcnn
# linha 22 nao tem face... m:GhostFaceNet | d: fastmtcnn
# linha 23 nao tem face... m:GhostFaceNet | d: fastmtcnn
# linha 24 nao tem face... m:GhostFaceNet | d: fastmtcnn
# linha 25 nao tem face... m:GhostFaceNet | d: fastmtcnn
# linha 26 nao tem face... m:GhostFaceNet | d: fastmtcnn
# linha 27 nao tem face... m:GhostFaceNet | d: fastmtcnn
# linha 28 nao tem face... m:GhostFaceNet | d: fastmtcnn
# linha 29 nao tem face... m:GhostFaceNet | d: fastmtcnn
# linha 30 nao tem face... m:GhostFaceNet | d: fastmtcnn
# linha 31 nao tem face... m:GhostFaceNet | d: fastmtcnn
# linha 32 nao tem face... m:GhostFaceNet | d: fastmtcnn
# linha 33 nao tem face... m:GhostFaceNet | d: fastmtcnn
# linha 34 nao tem face... m:GhostFaceNet | d: fastmtcnn
# linha 35 nao tem face... m:GhostFaceNet | d: fastmtcnn
# linha 36 nao tem face... m:GhostFaceNet | d: fastmtcnn
# linha 37 nao tem face... m:GhostFaceNet | d: fastmtcnn
# linha 38 nao tem face... m:GhostFaceNet | d: fastmtcnn
# linha 39 nao tem face... m:GhostFaceNet | d: fastmtcnn
# linha 40 nao tem face... m:GhostFaceNet | d: fastmtcnn
# linha 41 nao tem face... m:GhostFaceNet | d: fastmtcnn
# linha 42 nao tem face... m:GhostFaceNet | d: fastmtcnn
# linha 43 nao tem face... m:GhostFaceNet | d: fastmtcnn
# linha 44 nao tem face... m:GhostFaceNet | d: fastmtcnn
# linha 45 nao tem face... m:GhostFaceNet | d: fastmtcnn
# linha 46 nao tem face... m:GhostFaceNet | d: fastmtcnn
# linha 47 nao tem face... m:GhostFaceNet | d: fastmtcnn
# linha 48 nao tem face... m:GhostFaceNet | d: fastmtcnn
# linha 49 nao tem face... m:GhostFaceNet | d: fastmtcnn
# linha 50 nao tem face... m:GhostFaceNet | d: fastmtcnn
# linha 51 nao tem face... m:GhostFaceNet | d: fastmtcnn
# linha 52 nao tem face... m:GhostFaceNet | d: fastmtcnn
# linha 53 nao tem face... m:GhostFaceNet | d: fastmtcnn
# linha 54 nao tem face... m:GhostFaceNet | d: fastmtcnn
# linha 55 nao tem face... m:GhostFaceNet | d: fastmtcnn
# linha 56 nao tem face... m:GhostFaceNet | d: fastmtcnn
# linha 57 nao tem face... m:GhostFaceNet | d: fastmtcnn
# linha 58 nao tem face... m:GhostFaceNet | d: fastmtcnn
# linha 59 nao tem face... m:GhostFaceNet | d: fastmtcnn
# linha 60 nao tem face... m:GhostFaceNet | d: fastmtcnn
# linha 61 nao tem face... m:GhostFaceNet | d: fastmtcnn
# linha 62 nao tem face... m:GhostFaceNet | d: fastmtcnn
# linha 63 nao tem face... m:GhostFaceNet | d: fastmtcnn
# linha 64 nao tem face... m:GhostFaceNet | d: fastmtcnn
# linha 65 nao tem face... m:GhostFaceNet | d: fastmtcnn
# linha 66 nao tem face... m:GhostFaceNet | d: fastmtcnn
# linha 67 nao tem face... m:GhostFaceNet | d: fastmtcnn
# linha 68 nao tem face... m:GhostFaceNet | d: fastmtcnn
# linha 69 nao tem face... m:GhostFaceNet | d: fastmtcnn
# linha 70 nao tem face... m:GhostFaceNet | d: fastmtcnn
# linha 71 nao tem face... m:GhostFaceNet | d: fastmtcnn
# linha 72 nao tem face... m:GhostFaceNet | d: fastmtcnn
# linha 73 nao tem face... m:GhostFaceNet | d: fastmtcnn
# linha 74 nao tem face... m:GhostFaceNet | d: fastmtcnn
# linha 75 nao tem face... m:GhostFaceNet | d: fastmtcnn
# linha 76 nao tem face... m:GhostFaceNet | d: fastmtcnn
# linha 77 nao tem face... m:GhostFaceNet | d: fastmtcnn
# linha 78 nao tem face... m:GhostFaceNet | d: fastmtcnn
# linha 79 nao tem face... m:GhostFaceNet | d: fastmtcnn
# linha 80 nao tem face... m:GhostFaceNet | d: fastmtcnn
# linha 81 nao tem face... m:GhostFaceNet | d: fastmtcnn
# linha 82 nao tem face... m:GhostFaceNet | d: fastmtcnn
# linha 83 nao tem face... m:GhostFaceNet | d: fastmtcnn
# linha 84 nao tem face... m:GhostFaceNet | d: fastmtcnn
# linha 85 nao tem face... m:GhostFaceNet | d: fastmtcnn
# linha 86 nao tem face... m:GhostFaceNet | d: fastmtcnn
# linha 87 nao tem face... m:GhostFaceNet | d: fastmtcnn
# linha 88 nao tem face... m:GhostFaceNet | d: fastmtcnn
# linha 89 nao tem face... m:GhostFaceNet | d: fastmtcnn
# linha 90 nao tem face... m:GhostFaceNet | d: fastmtcnn
# linha 91 nao tem face... m:GhostFaceNet | d: fastmtcnn
# linha 92 nao tem face... m:GhostFaceNet | d: fastmtcnn
# linha 93 nao tem face... m:GhostFaceNet | d: fastmtcnn
# linha 94 nao tem face... m:GhostFaceNet | d: fastmtcnn
# linha 95 nao tem face... m:GhostFaceNet | d: fastmtcnn
# linha 96 nao tem face... m:GhostFaceNet | d: fastmtcnn
# linha 97 nao tem face... m:GhostFaceNet | d: fastmtcnn
# linha 98 nao tem face... m:GhostFaceNet | d: fastmtcnn
# linha 99 nao tem face... m:GhostFaceNet | d: fastmtcnn
# running m:sFace | d: fastmtcnn...
# linha 0 nao tem face... m:sFace | d: fastmtcnn
# linha 1 nao tem face... m:sFace | d: fastmtcnn
# linha 2 nao tem face... m:sFace | d: fastmtcnn
# linha 3 nao tem face... m:sFace | d: fastmtcnn
# linha 4 nao tem face... m:sFace | d: fastmtcnn
# linha 5 nao tem face... m:sFace | d: fastmtcnn
# linha 6 nao tem face... m:sFace | d: fastmtcnn
# linha 7 nao tem face... m:sFace | d: fastmtcnn
# linha 8 nao tem face... m:sFace | d: fastmtcnn
# linha 9 nao tem face... m:sFace | d: fastmtcnn
# linha 10 nao tem face... m:sFace | d: fastmtcnn
# linha 11 nao tem face... m:sFace | d: fastmtcnn
# linha 12 nao tem face... m:sFace | d: fastmtcnn
# linha 13 nao tem face... m:sFace | d: fastmtcnn
# linha 14 nao tem face... m:sFace | d: fastmtcnn
# linha 15 nao tem face... m:sFace | d: fastmtcnn
# linha 16 nao tem face... m:sFace | d: fastmtcnn
# linha 17 nao tem face... m:sFace | d: fastmtcnn
# linha 18 nao tem face... m:sFace | d: fastmtcnn
# linha 19 nao tem face... m:sFace | d: fastmtcnn
# linha 20 nao tem face... m:sFace | d: fastmtcnn
# linha 21 nao tem face... m:sFace | d: fastmtcnn
# linha 22 nao tem face... m:sFace | d: fastmtcnn
# linha 23 nao tem face... m:sFace | d: fastmtcnn
# linha 24 nao tem face... m:sFace | d: fastmtcnn
# linha 25 nao tem face... m:sFace | d: fastmtcnn
# linha 26 nao tem face... m:sFace | d: fastmtcnn
# linha 27 nao tem face... m:sFace | d: fastmtcnn
# linha 28 nao tem face... m:sFace | d: fastmtcnn
# linha 29 nao tem face... m:sFace | d: fastmtcnn
# linha 30 nao tem face... m:sFace | d: fastmtcnn
# linha 31 nao tem face... m:sFace | d: fastmtcnn
# linha 32 nao tem face... m:sFace | d: fastmtcnn
# linha 33 nao tem face... m:sFace | d: fastmtcnn
# linha 34 nao tem face... m:sFace | d: fastmtcnn
# linha 35 nao tem face... m:sFace | d: fastmtcnn
# linha 36 nao tem face... m:sFace | d: fastmtcnn
# linha 37 nao tem face... m:sFace | d: fastmtcnn
# linha 38 nao tem face... m:sFace | d: fastmtcnn
# linha 39 nao tem face... m:sFace | d: fastmtcnn
# linha 40 nao tem face... m:sFace | d: fastmtcnn
# linha 41 nao tem face... m:sFace | d: fastmtcnn
# linha 42 nao tem face... m:sFace | d: fastmtcnn
# linha 43 nao tem face... m:sFace | d: fastmtcnn
# linha 44 nao tem face... m:sFace | d: fastmtcnn
# linha 45 nao tem face... m:sFace | d: fastmtcnn
# linha 46 nao tem face... m:sFace | d: fastmtcnn
# linha 47 nao tem face... m:sFace | d: fastmtcnn
# linha 48 nao tem face... m:sFace | d: fastmtcnn
# linha 49 nao tem face... m:sFace | d: fastmtcnn
# linha 50 nao tem face... m:sFace | d: fastmtcnn
# linha 51 nao tem face... m:sFace | d: fastmtcnn
# linha 52 nao tem face... m:sFace | d: fastmtcnn
# linha 53 nao tem face... m:sFace | d: fastmtcnn
# linha 54 nao tem face... m:sFace | d: fastmtcnn
# linha 55 nao tem face... m:sFace | d: fastmtcnn
# linha 56 nao tem face... m:sFace | d: fastmtcnn
# linha 57 nao tem face... m:sFace | d: fastmtcnn
# linha 58 nao tem face... m:sFace | d: fastmtcnn
# linha 59 nao tem face... m:sFace | d: fastmtcnn
# linha 60 nao tem face... m:sFace | d: fastmtcnn
# linha 61 nao tem face... m:sFace | d: fastmtcnn
# linha 62 nao tem face... m:sFace | d: fastmtcnn
# linha 63 nao tem face... m:sFace | d: fastmtcnn
# linha 64 nao tem face... m:sFace | d: fastmtcnn
# linha 65 nao tem face... m:sFace | d: fastmtcnn
# linha 66 nao tem face... m:sFace | d: fastmtcnn
# linha 67 nao tem face... m:sFace | d: fastmtcnn
# linha 68 nao tem face... m:sFace | d: fastmtcnn
# linha 69 nao tem face... m:sFace | d: fastmtcnn
# linha 70 nao tem face... m:sFace | d: fastmtcnn
# linha 71 nao tem face... m:sFace | d: fastmtcnn
# linha 72 nao tem face... m:sFace | d: fastmtcnn
# linha 73 nao tem face... m:sFace | d: fastmtcnn
# linha 74 nao tem face... m:sFace | d: fastmtcnn
# linha 75 nao tem face... m:sFace | d: fastmtcnn
# linha 76 nao tem face... m:sFace | d: fastmtcnn
# linha 77 nao tem face... m:sFace | d: fastmtcnn
# linha 78 nao tem face... m:sFace | d: fastmtcnn
# linha 79 nao tem face... m:sFace | d: fastmtcnn
# linha 80 nao tem face... m:sFace | d: fastmtcnn
# linha 81 nao tem face... m:sFace | d: fastmtcnn
# linha 82 nao tem face... m:sFace | d: fastmtcnn
# linha 83 nao tem face... m:sFace | d: fastmtcnn
# linha 84 nao tem face... m:sFace | d: fastmtcnn
# linha 85 nao tem face... m:sFace | d: fastmtcnn
# linha 86 nao tem face... m:sFace | d: fastmtcnn
# linha 87 nao tem face... m:sFace | d: fastmtcnn
# linha 88 nao tem face... m:sFace | d: fastmtcnn
# linha 89 nao tem face... m:sFace | d: fastmtcnn
# linha 90 nao tem face... m:sFace | d: fastmtcnn
# linha 91 nao tem face... m:sFace | d: fastmtcnn
# linha 92 nao tem face... m:sFace | d: fastmtcnn
# linha 93 nao tem face... m:sFace | d: fastmtcnn
# linha 94 nao tem face... m:sFace | d: fastmtcnn
# linha 95 nao tem face... m:sFace | d: fastmtcnn
# linha 96 nao tem face... m:sFace | d: fastmtcnn
# linha 97 nao tem face... m:sFace | d: fastmtcnn
# linha 98 nao tem face... m:sFace | d: fastmtcnn
# linha 99 nao tem face... m:sFace | d: fastmtcnn

# %% [markdown]
# ### Verificação dos Resultados

# %%
# Exibe o DataFrame com os resultados
df.head()
# Out:
#            filename                                      relative_path  \
# 0  001_fe3347c0.jpg  imagens/Celebrity Faces Dataset/Angelina Jolie...
# 1  002_8f8da10e.jpg  imagens/Celebrity Faces Dataset/Angelina Jolie...
# 2  003_57612506.jpg  imagens/Celebrity Faces Dataset/Angelina Jolie...
# 3  004_f61e7d0c.jpg  imagens/Celebrity Faces Dataset/Angelina Jolie...
# 4  005_582c121a.jpg  imagens/Celebrity Faces Dataset/Angelina Jolie...
#
#   CPU_opencv_Dlib CPU_opencv_Facenet512 CPU_opencv_Facenet CPU_opencv_ArcFace  \
# 0            None              3.491603           2.198748           1.934824
# 1            None              0.407442           0.338084           0.360428
# 2            None              0.393832           0.338482           0.369146
# 3            None               0.28905           0.258803           0.267865
# 4            None              0.373008            0.33229           0.326113
#
#   CPU_opencv_OpenFace CPU_opencv_DeepID CPU_opencv_DeepFace  \
# 0            2.060678          0.275469                None
# 1            0.241422          0.140599                None
# 2            0.213638          0.163696                None
# 3            0.126679          0.061147                None
# 4             0.20209          0.136473                None
#
#   CPU_opencv_GhostFaceNet  ... CPU_yunet_sFace CPU_fastmtcnn_Dlib  \
# 0                4.458306  ...            None               None
# 1                    0.42  ...            None               None
# 2                0.384802  ...            None               None
# 3                0.350876  ...            None               None
# 4                0.360807  ...            None               None
#
#   CPU_fastmtcnn_Facenet512 CPU_fastmtcnn_Facenet CPU_fastmtcnn_ArcFace  \
# 0                     None                  None                  None
# 1                     None                  None                  None
# 2                     None                  None                  None
# 3                     None                  None                  None
# 4                     None                  None                  None
#
#   CPU_fastmtcnn_OpenFace CPU_fastmtcnn_DeepID CPU_fastmtcnn_DeepFace  \
# 0                   None                 None                   None
# 1                   None                 None                   None
# 2                   None                 None                   None
# 3                   None                 None                   None
# 4                   None                 None                   None
#
#   CPU_fastmtcnn_GhostFaceNet CPU_fastmtcnn_sFace
# 0                       None                None
# 1                       None                None
# 2                       None                None
# 3                       None                None
# 4                       None                None
#
# [5 rows x 74 columns]
